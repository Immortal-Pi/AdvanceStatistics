# %%
import klib
import seaborn as sns
import pandas as pd

# %%
data= sns.load_dataset('titanic')

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
klib.cat_plot(data)
# Out:
# E:\anaconda3\envs\stats\Lib\site-packages\klib\describe.py:120: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   data.loc[data[col].isin(value_counts_idx_top), col] = 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 klib.cat_plot(data)
#
# File E:\anaconda3\envs\stats\Lib\site-packages\klib\describe.py:125, in cat_plot(data, figsize, top, bottom, bar_color_top, bar_color_bottom)
#     122 data.loc[((data[col] != 10) & (data[col] != 0)), col] = 5  # noqa: PLR2004
#     123 data[col] = data[col].rolling(2, min_periods=1).mean()
# --> 125 value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
# ...

# %%
klib.corr_mat(data)
# Out:
# E:\anaconda3\envs\stats\Lib\site-packages\klib\describe.py:271: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   return corr.style.applymap(color_negative_red).format("{:.2f}", na_rep="-")
# <style type="text/css">
# #T_0840a_row0_col0, #T_0840a_row0_col4, #T_0840a_row0_col5, #T_0840a_row1_col1, #T_0840a_row1_col3, #T_0840a_row1_col4, #T_0840a_row1_col6, #T_0840a_row1_col7, #T_0840a_row2_col2, #T_0840a_row2_col5, #T_0840a_row2_col6, #T_0840a_row2_col7, #T_0840a_row3_col1, #T_0840a_row3_col3, #T_0840a_row3_col4, #T_0840a_row3_col5, #T_0840a_row4_col0, #T_0840a_row4_col1, #T_0840a_row4_col3, #T_0840a_row4_col4, #T_0840a_row4_col5, #T_0840a_row5_col0, #T_0840a_row5_col2, #T_0840a_row5_col3, #T_0840a_row5_col4, #T_0840a_row5_col5, #T_0840a_row6_col1, #T_0840a_row6_col2, #T_0840a_row6_col6, #T_0840a_row6_col7, #T_0840a_row7_col1, #T_0840a_row7_col2, #T_0840a_row7_col6, #T_0840a_row7_col7 {
#   color: None;
# }
# ...

# %%
klib.corr_plot(data)
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(data)
# Out:
# <Axes: xlabel='pclass', ylabel='Density'>
